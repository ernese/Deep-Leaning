# %% [markdown]
# #Assigment 3: Identifying cracks and damages in structures (Concrete structures)
# <br>42028 Deep Learning and Convolutional Neural Network - Autumn 2020
#
# <br>Carlos Mario Carvajal Moreno. Student ID: 13144148
# <br>Andres Felipe Lagos. Student ID: 13092248
# <br>Ernest Ilustre.  Student ID: 12763239

# %%
#Connecting to Google drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#Importing the necessary libraries

import numpy as np
import matplotlib.pyplot as plt
import os
import zipfile
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import LabelBinarizer
from keras.callbacks import ModelCheckpoint
from keras import models
from keras import layers
from keras import optimizers
from keras.preprocessing import image
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input, decode_predictions
from keras.applications.vgg16 import VGG16
from keras.models import model_from_json

# %%
cd /content/gdrive/My Drive/A3
# Out:
# /content/gdrive/My Drive/A3

# %%
ls
# Out:
# A3_CNN_Multiclass.ipynb  VGG16_A3_CNN_Pavement.ipynb  VGG19_A3_CNN_Wall.ipynb
# Concrete_Data_Final.zip  VGG16_A3_CNN_Wall.ipynb      Weights/
# multiclass_model.json    VGG19_A3_CNN_Deck.ipynb
# VGG16_A3_CNN_Deck.ipynb  VGG19_A3_CNN_Pavement.ipynb

# %%
#Extraction of data and placing it in the temporary folder. The models work a lot better
local_zip = '/content/gdrive/My Drive/A3/Concrete_Data_Final.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
#Setting the path directory for training and validation sets
base_dir = '/tmp/Concrete_Data_Final'
train_dir = os.path.join(base_dir, 'Train/Wall')
validation_dir = os.path.join(base_dir, 'Val/Wall')
test_dir = os.path.join(base_dir, 'Test/Wall')

#Train
# Directory with training Pavement Cracked Pictures
train_cracked_dir = os.path.join(train_dir, 'Cracked')
# Directory with training Pavement Uncracked Pictures
train_Uncracked_dir = os.path.join(train_dir, 'Uncracked')


#Val
# Directory with validation Pavement Cracked pictures
val_cracked_dir = os.path.join(validation_dir, 'Cracked')
# Directory with validation Pavement Uncracked pictures
val_Uncracked_dir = os.path.join(validation_dir, 'Uncracked')


#Test
# Directory with validation Pavement Cracked pictures
test_cracked_dir = os.path.join(test_dir, 'Cracked')
# Directory with validation Pavement Uncracked pictures
test_Uncracked_dir = os.path.join(test_dir, 'Uncracked')

# %%
# All images are rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True,
                                   brightness_range = (0.9,1.1),
                                   fill_mode='nearest'
                                   )
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
batch_size = 16
image_size = 256

# Flow training images in batches of 16 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(image_size, image_size),  # Images are size 100X100
        batch_size= batch_size,
        class_mode='binary')

# Flow validation images in batches of 16 using test_datagen generator
validation_generator = val_datagen.flow_from_directory(
        validation_dir,
        target_size=(image_size, image_size),
        batch_size= batch_size,
        class_mode='binary')

# Flow validation images in batches of 16 using test_datagen generator
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(image_size, image_size),
        batch_size= batch_size,
        class_mode='binary')
# Out:
# Found 5527 images belonging to 2 classes.
# Found 1579 images belonging to 2 classes.
# Found 11032 images belonging to 2 classes.

# %%
class_dict = train_generator.class_indices
class_dict
# Out:
# {'Cracked': 0, 'Uncracked': 1}

# %%
#Downloading the inception ResNet V2 model with imagenet weights
conv_base = VGG16(include_top=False, weights='imagenet', input_shape=(256,256,3))
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step

# %%
model = models.Sequential()
model.add(conv_base)

model.add(layers.Flatten())

model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.BatchNormalization())

model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.BatchNormalization())

model.add(layers.Dense(1, activation='sigmoid'))

# %%
conv_base.summary()
for layer in conv_base.layers[:-4]:
    layer.trainable = False
 
# Check the trainable status of the individual layers
for layer in conv_base.layers:
    print(layer, layer.trainable)


model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# <keras.engine.input_layer.InputLayer object at 0x7f2053321240> False
# <keras.layers.convolutional.Conv2D object at 0x7f20091526a0> False
# <keras.layers.convolutional.Conv2D object at 0x7f20091529e8> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f2009152f98> False
# <keras.layers.convolutional.Conv2D object at 0x7f200448eb00> False
# <keras.layers.convolutional.Conv2D object at 0x7f20012fea58> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f20012fee10> False
# <keras.layers.convolutional.Conv2D object at 0x7f20012fec50> False
# <keras.layers.convolutional.Conv2D object at 0x7f2003b65710> False
# <keras.layers.convolutional.Conv2D object at 0x7f2003b69320> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f2003b69da0> False
# <keras.layers.convolutional.Conv2D object at 0x7f2003b69ba8> False
# <keras.layers.convolutional.Conv2D object at 0x7f2003b6ee80> False
# <keras.layers.convolutional.Conv2D object at 0x7f2003b76518> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f2003b76da0> False
# <keras.layers.convolutional.Conv2D object at 0x7f2003b76d68> True
# <keras.layers.convolutional.Conv2D object at 0x7f2003b7cb38> True
# <keras.layers.convolutional.Conv2D object at 0x7f20036b5710> True
# <keras.layers.pooling.MaxPooling2D object at 0x7f20036b5f28> True
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 8, 8, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               16777728
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 31,759,681
# Trainable params: 24,122,369
# Non-trainable params: 7,637,312
# _________________________________________________________________

# %%
#compiling the model
model.compile(optimizer= optimizers.RMSprop(learning_rate=0.001),
              loss= 'binary_crossentropy',
              metrics=['accuracy'])

# %%
#checkpoint = ModelCheckpoint('weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss', save_best_only=True, verbose=1, period=3)
filepath='/content/gdrive/My Drive/A3/Weights/Wall_weights.{epoch:02d}-{val_loss:.2f}.hdf5'
checkpoint= ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)
json_string  = model.to_json()
f = open("wall_model.json", 'w')
f.write(json_string)
f.close()

# %%
# Train the model
history = model.fit(
      train_generator,
      steps_per_epoch= train_generator.n//train_generator.batch_size,
      epochs=20,
      validation_data=validation_generator,
      validation_steps= validation_generator.n//train_generator.batch_size,
      callbacks = [checkpoint],
      verbose=1,
      )
# Out:
# Epoch 1/20
# 345/345 [==============================] - 111s 321ms/step - loss: 0.6219 - accuracy: 0.7024 - val_loss: 0.4943 - val_accuracy: 0.7066
# Epoch 2/20
# 345/345 [==============================] - 107s 311ms/step - loss: 0.4809 - accuracy: 0.7799 - val_loss: 0.3078 - val_accuracy: 0.7729
# Epoch 3/20
# 345/345 [==============================] - 107s 309ms/step - loss: 0.4288 - accuracy: 0.8089 - val_loss: 0.7181 - val_accuracy: 0.7697
# Epoch 4/20
# 345/345 [==============================] - 106s 307ms/step - loss: 0.4153 - accuracy: 0.8111 - val_loss: 0.4932 - val_accuracy: 0.7639
# Epoch 5/20
# 345/345 [==============================] - 106s 307ms/step - loss: 0.4042 - accuracy: 0.8240 - val_loss: 0.7130 - val_accuracy: 0.7799
# Epoch 6/20
# 345/345 [==============================] - 105s 304ms/step - loss: 0.3925 - accuracy: 0.8278 - val_loss: 0.6332 - val_accuracy: 0.8068
# Epoch 7/20
# 345/345 [==============================] - 104s 303ms/step - loss: 0.3969 - accuracy: 0.8276 - val_loss: 0.6934 - val_accuracy: 0.8004
# Epoch 8/20
# 345/345 [==============================] - 101s 294ms/step - loss: 0.3840 - accuracy: 0.8378 - val_loss: 0.2718 - val_accuracy: 0.7953
# Epoch 9/20
# 345/345 [==============================] - 102s 296ms/step - loss: 0.3866 - accuracy: 0.8365 - val_loss: 0.5705 - val_accuracy: 0.7825
# Epoch 10/20
# 345/345 [==============================] - 102s 295ms/step - loss: 0.3704 - accuracy: 0.8421 - val_loss: 0.3466 - val_accuracy: 0.8023
# Epoch 11/20
# 345/345 [==============================] - 101s 292ms/step - loss: 0.3741 - accuracy: 0.8490 - val_loss: 0.4460 - val_accuracy: 0.8292
# Epoch 12/20
# 345/345 [==============================] - 100s 289ms/step - loss: 0.3723 - accuracy: 0.8450 - val_loss: 0.2027 - val_accuracy: 0.8017
# Epoch 13/20
# 345/345 [==============================] - 100s 291ms/step - loss: 0.3729 - accuracy: 0.8405 - val_loss: 0.2912 - val_accuracy: 0.8221
# Epoch 14/20
# 345/345 [==============================] - 101s 292ms/step - loss: 0.3629 - accuracy: 0.8481 - val_loss: 0.4260 - val_accuracy: 0.8196
# Epoch 15/20
# 345/345 [==============================] - 100s 291ms/step - loss: 0.3745 - accuracy: 0.8492 - val_loss: 0.4847 - val_accuracy: 0.7370
# Epoch 16/20
# 345/345 [==============================] - 100s 289ms/step - loss: 0.3582 - accuracy: 0.8570 - val_loss: 0.2115 - val_accuracy: 0.8292
# Epoch 17/20
# 345/345 [==============================] - 100s 291ms/step - loss: 0.3605 - accuracy: 0.8499 - val_loss: 0.4096 - val_accuracy: 0.6392
# Epoch 18/20
# 345/345 [==============================] - 100s 291ms/step - loss: 0.3597 - accuracy: 0.8534 - val_loss: 0.5775 - val_accuracy: 0.7997
# Epoch 19/20
# 345/345 [==============================] - 100s 289ms/step - loss: 0.3648 - accuracy: 0.8461 - val_loss: 0.1389 - val_accuracy: 0.7953
# Epoch 20/20
# 345/345 [==============================] - 101s 292ms/step - loss: 0.3578 - accuracy: 0.8494 - val_loss: 0.6607 - val_accuracy: 0.7972

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
test_loss, test_acc = model.evaluate(test_generator)
test_acc
# Out:
# 690/690 [==============================] - 35s 51ms/step
# 0.9537708759307861

# %% [markdown]
# ## Loading a saved model.

# %%
## Go to the /tmp folder and copy the name of the last saved model
#modelv2=tf.keras.models.load_model('/content/drive/My Drive/Weights/Pavement_weights.10-0.26.hdf5')

# %%
#compiling the model
modelv2.compile(optimizer= tf.keras.optimizers.Adamax(learning_rate=0.001),
              loss= 'binary_crossentropy',
              metrics=['accuracy'])

# %%
#checkpoint = ModelCheckpoint('weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss', save_best_only=True, verbose=1, period=3)
#epath='/content/drive/My Drive/Weights/Pavement_weights2.{epoch:02d}-{val_loss:.2f}.hdf5'
#checkpoint= ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)

# %%
# Train the model
history = modelv2.fit(
      train_generator,
      steps_per_epoch= train_generator.n//train_generator.batch_size,
      epochs=20,
      validation_data=validation_generator,
      validation_steps= validation_generator.n//train_generator.batch_size,
      #callbacks = [checkpoint],
      verbose=1,
      )
