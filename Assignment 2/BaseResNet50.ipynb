# %%
#google
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#import packages
import os
import tensorflow as tf
import keras
from keras import layers
from keras.models import Model
from keras import optimizers
from keras.layers import Dropout, Flatten, Dense, BatchNormalization, GlobalAveragePooling2D
from sklearn.preprocessing import LabelBinarizer
from keras.callbacks import ModelCheckpoint
from keras.optimizers import RMSprop, SGD, Adam
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img 
from keras.applications.resnet import ResNet50
# Out:
# Using TensorFlow backend.

# %%
#load dataset
train_path = '/content/gdrive/My Drive/42028-DL-CNN-2020/A2/dataset1/train/' #80
valid_path = '/content/gdrive/My Drive/42028-DL-CNN-2020/A2/dataset1/val/' #10
test_path = '/content/gdrive/My Drive/42028-DL-CNN-2020/A2/dataset1/test/' #10

# %%
#ImageGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
#datagen flow for multi-class
train_generator = train_datagen.flow_from_directory(train_path, target_size=(224,224),
    class_mode='categorical', batch_size=8)
valid_generator = test_datagen.flow_from_directory(valid_path, target_size=(224,224),
    class_mode='categorical', batch_size=8)
test_generator = test_datagen.flow_from_directory(test_path, target_size=(224,224),
    class_mode='categorical', batch_size=8)
# Out:
# Found 900 images belonging to 4 classes.
# Found 113 images belonging to 4 classes.
# Found 112 images belonging to 4 classes.

# %%
#resnet101
model = ResNet50(weights= None, include_top = True, classes = 4)

# %%
#compile model
model.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(lr=1e-5), metrics=['acc'])

# %%
#train model
history = model.fit_generator(
      train_generator,
      steps_per_epoch=100,  
      epochs=25,
      validation_data=valid_generator,
      validation_steps=10,  
      verbose=1)
# Out:
# Epoch 1/25
# 100/100 [==============================] - 453s 5s/step - loss: 1.2089 - acc: 0.5038 - val_loss: 1.6818 - val_acc: 0.2500
# Epoch 2/25
# 100/100 [==============================] - 76s 765ms/step - loss: 1.0155 - acc: 0.5791 - val_loss: 2.1668 - val_acc: 0.3014
# Epoch 3/25
# 100/100 [==============================] - 22s 223ms/step - loss: 0.8948 - acc: 0.6445 - val_loss: 4.9469 - val_acc: 0.2466
# Epoch 4/25
# 100/100 [==============================] - 22s 218ms/step - loss: 0.8161 - acc: 0.6633 - val_loss: 1.6644 - val_acc: 0.4875
# Epoch 5/25
# 100/100 [==============================] - 23s 226ms/step - loss: 0.8018 - acc: 0.6671 - val_loss: 1.3456 - val_acc: 0.5068
# Epoch 6/25
# 100/100 [==============================] - 22s 221ms/step - loss: 0.6747 - acc: 0.7425 - val_loss: 0.0044 - val_acc: 0.6849
# Epoch 7/25
# 100/100 [==============================] - 22s 222ms/step - loss: 0.6377 - acc: 0.7751 - val_loss: 0.3488 - val_acc: 0.8625
# Epoch 8/25
# 100/100 [==============================] - 22s 218ms/step - loss: 0.6173 - acc: 0.7839 - val_loss: 0.5117 - val_acc: 0.8493
# Epoch 9/25
# 100/100 [==============================] - 22s 221ms/step - loss: 0.6009 - acc: 0.7651 - val_loss: 0.0426 - val_acc: 0.8356
# Epoch 10/25
# 100/100 [==============================] - 22s 219ms/step - loss: 0.5688 - acc: 0.7802 - val_loss: 0.4095 - val_acc: 0.9250
# Epoch 11/25
# 100/100 [==============================] - 23s 226ms/step - loss: 0.5397 - acc: 0.8028 - val_loss: 0.2866 - val_acc: 0.8630
# Epoch 12/25
# 100/100 [==============================] - 22s 218ms/step - loss: 0.5120 - acc: 0.8150 - val_loss: 1.8178e-04 - val_acc: 0.8630
# Epoch 13/25
# 100/100 [==============================] - 22s 221ms/step - loss: 0.4466 - acc: 0.8166 - val_loss: 0.7068 - val_acc: 0.8625
# Epoch 14/25
# 100/100 [==============================] - 23s 226ms/step - loss: 0.5049 - acc: 0.8141 - val_loss: 0.2062 - val_acc: 0.8219
# Epoch 15/25
# 100/100 [==============================] - 22s 218ms/step - loss: 0.4803 - acc: 0.8241 - val_loss: 0.2112 - val_acc: 0.9041
# Epoch 16/25
# 100/100 [==============================] - 22s 219ms/step - loss: 0.4654 - acc: 0.8455 - val_loss: 0.6443 - val_acc: 0.8625
# Epoch 17/25
# 100/100 [==============================] - 22s 220ms/step - loss: 0.4854 - acc: 0.8141 - val_loss: 0.1547 - val_acc: 0.8493
# Epoch 18/25
# 100/100 [==============================] - 22s 220ms/step - loss: 0.3771 - acc: 0.8618 - val_loss: 4.6089 - val_acc: 0.8219
# Epoch 19/25
# 100/100 [==============================] - 22s 224ms/step - loss: 0.4870 - acc: 0.8254 - val_loss: 0.1272 - val_acc: 0.8375
# Epoch 20/25
# 100/100 [==============================] - 22s 220ms/step - loss: 0.4530 - acc: 0.8288 - val_loss: 0.2792 - val_acc: 0.8630
# Epoch 21/25
# 100/100 [==============================] - 22s 215ms/step - loss: 0.4274 - acc: 0.8308 - val_loss: 0.2197 - val_acc: 0.8767
# Epoch 22/25
# 100/100 [==============================] - 21s 213ms/step - loss: 0.4520 - acc: 0.8354 - val_loss: 0.4430 - val_acc: 0.8125
# Epoch 23/25
# 100/100 [==============================] - 22s 219ms/step - loss: 0.4670 - acc: 0.8266 - val_loss: 0.2997 - val_acc: 0.8630
# Epoch 24/25
# 100/100 [==============================] - 22s 216ms/step - loss: 0.4263 - acc: 0.8480 - val_loss: 2.0788e-04 - val_acc: 0.8493
# Epoch 25/25
# 100/100 [==============================] - 22s 220ms/step - loss: 0.3825 - acc: 0.8550 - val_loss: 0.1719 - val_acc: 0.8500

# %%
#plot graph
import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
test_loss, test_acc = model.evaluate(test_generator)
test_acc
# Out:
# 14/14 [==============================] - 60s 4s/step
# 0.8303571343421936
